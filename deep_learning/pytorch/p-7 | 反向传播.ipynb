# %% [markdown]
# # 反向传播

# %% [markdown]
# ${\partial E \over \partial w_{jk}} = \begin{pmatrix}O_k - t_k\end{pmatrix}O_k \begin{pmatrix}1 - O_k\end{pmatrix}O_j^J$
# ![%E6%88%AA%E5%B1%8F2021-05-03%20%E4%B8%8B%E5%8D%885.47.23.png](attachment:%E6%88%AA%E5%B1%8F2021-05-03%20%E4%B8%8B%E5%8D%885.47.23.png)

# %% [markdown]
# 不知道什么鬼，原理就是求导，纠正
