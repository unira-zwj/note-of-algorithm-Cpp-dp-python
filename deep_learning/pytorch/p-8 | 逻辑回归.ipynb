# %% [markdown]
# # 逻辑回归
# - $y=xw+b$
# - $y=\sigma (xw+b)$
# - $\sigma$  :sigmoid or logistic

# %% [markdown]
# ![%E6%88%AA%E5%B1%8F2021-05-22%20%E4%B8%8A%E5%8D%882.26.45.png](attachment:%E6%88%AA%E5%B1%8F2021-05-22%20%E4%B8%8A%E5%8D%882.26.45.png)
