# %% [markdown]
# # 分类问题的损失函数
# ![%E6%88%AA%E5%B1%8F2021-05-22%20%E4%B8%8A%E5%8D%882.41.37.png](attachment:%E6%88%AA%E5%B1%8F2021-05-22%20%E4%B8%8A%E5%8D%882.41.37.png)

# %% [markdown]
# ## Cross Entropy Loss交叉熵
# - 熵越大越不稳定
# ![%E6%88%AA%E5%B1%8F2021-05-23%20%E4%B8%8B%E5%8D%882.03.55.png](attachment:%E6%88%AA%E5%B1%8F2021-05-23%20%E4%B8%8B%E5%8D%882.03.55.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch
from torch.nn import functional as F
x = torch.randn(1, 784)
w = torch.randn(10,784)
logits = x @ w.t()
# cross_entropy = softmax + log + nll_loss
F.cross_entropy(logits, torch.tensor([3]))
# pred = F.softmax(logits, dim=1)
# pred_log = torch.log(pred)
# F.nll_loss(pred_log, torch.tensor([3]))
# Out:
# tensor(4.7391)
